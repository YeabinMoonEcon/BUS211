# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/yeabinmoon/Documents/ibs_course/Summer2023/BUS243/PS/PS3/sample.csv', index_col=0)

# %%
df.text.apply(len).idxmax()
# Out:
# 40261

# %%
temp = df.loc[df.text.apply(len).idxmax()].text

# %%
Counter(temp.split()).most_common()
# Out:
# [('the', 49),
#  ('I', 44),
#  ('a', 26),
#  ('and', 26),
#  ('to', 25),
#  ('my', 24),
#  ('of', 18),
#  ('that', 18),
#  ('was', 14),
#  ('for', 12),
#  ('had', 11),
#  ('in', 10),
#  ('it', 9),
#  ('me', 8),
#  ('room', 8),
#  ('with', 7),
#  ('over', 7),
#  ('on', 7),
#  ('find', 6),
#  ('-', 6),
#  ('four', 5),
#  ('when', 5),
#  ('said', 5),
#  ('check', 4),
#  ('out', 4),
#  ('group', 4),
#  ('rate', 4),
#  ('get', 4),
#  ('She', 4),
#  ('not', 4),
#  ('been', 4),
#  ('she', 4),
#  ('have', 4),
#  ('would', 4),
#  ('left', 4),
#  ('bag', 4),
#  ('but', 4),
#  ('them', 4),
#  ('were', 4),
#  ('two', 4),
#  ('charges', 4),
#  ('bill.', 4),
#  ('from', 3),
#  ('The', 3),
#  ('night', 3),
#  ('call', 3),
#  ('person', 3),
#  ('did', 3),
#  ('someone', 3),
#  ('it.', 3),
#  ('after', 3),
#  ('called', 3),
#  ('top', 3),
#  ("I'm", 3),
#  ('at', 3),
#  ("didn't", 3),
#  ('tray', 3),
#  ('you', 3),
#  ('is', 3),
#  ('into', 3),
#  ('Then', 3),
#  ('their', 3),
#  ('charges.', 3),
#  ('manager', 3),
#  ('asked', 3),
#  ('he', 3),
#  ('few', 2),
#  ('nice', 2),
#  ('staying', 2),
#  ('stay', 2),
#  ("couldn't", 2),
#  ('either.', 2),
#  ('times', 2),
#  ('Why', 2),
#  ('told', 2),
#  ('comforter', 2),
#  ('It', 2),
#  ('because', 2),
#  ('minor', 2),
#  ('probably', 2),
#  ('there,', 2),
#  ('around', 2),
#  ('service', 2),
#  ('still', 2),
#  ('there', 2),
#  ('2', 2),
#  ('town.', 2),
#  ('am', 2),
#  ('packing', 2),
#  ('up', 2),
#  ('toiletry', 2),
#  ('moved', 2),
#  ('ziplock', 2),
#  ('housekeeping', 2),
#  ('out.', 2),
#  ('Strike', 2),
#  ('registration', 2),
#  ('this', 2),
#  ('clothes', 2),
#  ('heart', 2),
#  ('one', 2),
#  ('iPad', 2),
#  ('dresser', 2),
#  ('put', 2),
#  ('nor', 2),
#  ('manager,', 2),
#  ('security', 2),
#  ('&', 2),
#  ('leave', 2),
#  ('suite', 2),
#  ('minutes', 2),
#  ('front', 2),
#  ("hadn't", 2),
#  ('time', 2),
#  ('copy', 2),
#  ('monitor', 2),
#  ('amount,', 2),
#  ('are', 2),
#  ('My', 1),
#  ('entire', 1),
#  ('experience', 1),
#  ('Royal', 1),
#  ('Sonesta', 1),
#  ('New', 1),
#  ('Orleans', 1),
#  ('disappointment', 1),
#  ('booking', 1),
#  ('exception', 1),
#  ('employees.', 1),
#  ('(we', 1),
#  ('block)', 1),
#  ("friend's", 1),
#  ('40th.', 1),
#  ('online', 1),
#  ('portal', 1),
#  ("wouldn't", 1),
#  ('allow', 1),
#  ('book', 1),
#  ('less', 1),
#  ('than', 1),
#  ('telephone', 1),
#  ('operators', 1),
#  ('offer', 1),
#  ('sales', 1),
#  ('(4)', 1),
#  ('rate.', 1),
#  ('times?', 1),
#  ("doesn't", 1),
#  ('return', 1),
#  ('calls', 1),
#  ('(I', 1),
#  ('tried', 1),
#  ('week', 1),
#  ('her', 1),
#  ('multiple', 1),
#  ('course', 1),
#  ('day).', 1),
#  ('else', 1),
#  ('department', 1),
#  ('handle', 1),
#  ('Several', 1),
#  ('days', 1),
#  ('booked,', 1),
#  ('calling', 1),
#  ('finally', 1),
#  ('wrong', 1),
#  ('(at', 1),
#  ('least', 1),
#  ('got', 1),
#  ('cheaper', 1),
#  ('rate).', 1),
#  ('some', 1),
#  ('sort', 1),
#  ('faded', 1),
#  ('red', 1),
#  ('stain', 1),
#  ('(hurricane/fruit', 1),
#  ('punch', 1),
#  ('spill).', 1),
#  ('obvious', 1),
#  ('should', 1),
#  ('resulted', 1),
#  ('getting', 1),
#  ('tossed.', 1),
#  ('expect', 1),
#  ('more', 1),
#  ('Days', 1),
#  ('Inn.', 1),
#  ('complain', 1),
#  ('already', 1),
#  ('unpacked', 1),
#  ('relatively', 1),
#  ('issue', 1),
#  ('overlooked', 1),
#  ('if', 1),
#  ('what', 1),
#  ('happened.', 1),
#  ('2nd', 1),
#  ('hotel', 1),
#  ('6', 1),
#  ('PM', 1),
#  ('empty', 1),
#  ('food', 1),
#  ('sitting', 1),
#  ('hall.', 1),
#  ('That', 1),
#  ('AM', 1),
#  ('8', 1),
#  ('AM.', 1),
#  ("That's", 1),
#  ('right,', 1),
#  ('14', 1),
#  ('hours', 1),
#  ('later.', 1),
#  ('So', 1),
#  ('those', 1),
#  ('think', 1),
#  ('being', 1),
#  ('petty', 1),
#  ('hold', 1),
#  ('your', 1),
#  ('seats', 1),
#  ('incompetence', 1),
#  ('train', 1),
#  ('rolling', 1),
#  ('As', 1),
#  ('morning', 1),
#  ('2,', 1),
#  ('behind', 1),
#  ('towels', 1),
#  ('underneath', 1),
#  ('vanity.', 1),
#  ('world', 1),
#  ('do', 1),
#  ('that?', 1),
#  ('off,', 1),
#  ('toiletries', 1),
#  ('gone.', 1),
#  ('inside', 1),
#  ('bag.', 1),
#  ('assume', 1),
#  ('fell', 1),
#  ('decided', 1),
#  ('throw', 1),
#  ('1', 1),
#  ('(but', 1),
#  ('commented', 1),
#  ('out).', 1),
#  ('cannot', 1),
#  ('locate', 1),
#  ('Downy', 1),
#  ('wrinkle', 1),
#  ('spray.', 1),
#  ('Small', 1),
#  ('bottle,', 1),
#  ('goes', 1),
#  ('works', 1),
#  ('wonders', 1),
#  ('taking', 1),
#  ('wrinkles.', 1),
#  ('scoured', 1),
#  ('spray', 1),
#  ('bottle', 1),
#  ('Now,', 1),
#  ('gear', 1),
#  ("can't", 1),
#  ('strap', 1),
#  ('pairs', 1),
#  ('Garmin', 1),
#  ('devices.', 1),
#  ('draped', 1),
#  ('chair', 1),
#  ('workout', 1),
#  ('so', 1),
#  ('could', 1),
#  ('dry.', 1),
#  ('literally', 1),
#  ('checked', 1),
#  ('ever', 1),
#  ('part', 1),
#  ("Couldn't", 1),
#  ('anywhere.', 1),
#  ('However,', 1),
#  ('chargers', 1),
#  ('apple', 1),
#  ('pencil', 1),
#  ('thrown', 1),
#  ('placed', 1),
#  ('drawer', 1),
#  ('nightstands', 1),
#  ('(as', 1),
#  ('might', 1),
#  ('surmise', 1),
#  ('local', 1),
#  ('magazines', 1),
#  ('either).', 1),
#  ('Neither', 1),
#  ('sets', 1),
#  ('expensive', 1),
#  ('headphones', 1),
#  ('touched.', 1),
#  ('Big', 1),
#  ('strike', 1),
#  ('3', 1),
#  ('came', 1),
#  ('instead.', 1),
#  ('They', 1),
#  ('polite,', 1),
#  ('took', 1),
#  ('copious', 1),
#  ('notes,', 1),
#  ('downloaded', 1),
#  ('entry', 1),
#  ('logs', 1),
#  ('door.', 1),
#  ('take', 1),
#  ("what's", 1),
#  ('stuff', 1),
#  ("host's", 1),
#  ('(stepping', 1),
#  ('there).', 1),
#  ('proceed', 1),
#  ('about', 1),
#  ('45', 1),
#  ('guards', 1),
#  ('leave.', 1),
#  ('At', 1),
#  ('point', 1),
#  ('given', 1),
#  ('summary', 1),
#  ('tell', 1),
#  ('desk', 1),
#  ('host', 1),
#  ('wish', 1),
#  ('speak', 1),
#  ('end', 1),
#  ('wanted', 1),
#  ('check-out.', 1),
#  ('number', 1),
#  ('(lists', 1),
#  ('5-7', 1),
#  ('places', 1),
#  ('int', 1),
#  ('hotel)', 1),
#  ('asks', 1),
#  ('ok?', 1),
#  ('need', 1),
#  ('see', 1),
#  ('where', 1),
#  ('manager.', 1),
#  ('hear', 1),
#  ('ask', 1),
#  ('then', 1),
#  ('other', 1),
#  ('suggested', 1),
#  ('next', 1),
#  ('they', 1),
#  ("don't", 1),
#  ('use', 1),
#  ('phones', 1),
#  ('talking', 1),
#  ('customers.', 1),
#  ('will', 1),
#  ('bring', 1),
#  ('A', 1),
#  ('later', 1),
#  ('Randy,', 1),
#  ('comes', 1),
#  ('without', 1),
#  ('explained', 1),
#  ('situation', 1),
#  ('how', 1),
#  ('much', 1),
#  ('cost', 1),
#  ('deducted', 1),
#  ('only', 1),
#  ('Not', 1),
#  ('exactly', 1),
#  ('great', 1),
#  ('move', 1),
#  ('towards', 1),
#  ('satisfying', 1),
#  ('clearly', 1),
#  ('annoyed', 1),
#  ('customer.', 1),
#  ('handed', 1),
#  ('actual', 1),
#  ('There', 1),
#  ('4', 1),
#  ('totaling', 1),
#  ('little', 1),
#  ('shy', 1),
#  ('$100', 1),
#  ('restaurants,', 1),
#  ('bar,', 1),
#  ('coffee', 1),
#  ('shop', 1),
#  ('too.', 1),
#  ('In', 1),
#  ('fact', 1),
#  ('party', 1),
#  ('third', 1),
#  ('half', 1),
#  ('way', 1),
#  ('across', 1),
#  ('tour,', 1),
#  ('circled', 1),
#  ('questionable', 1),
#  ('charges,', 1),
#  ('look', 1),
#  ('while', 1),
#  ('gone', 1),
#  ('refused', 1),
#  ('When', 1),
#  ('returned', 1),
#  ('1:30,', 1),
#  ('randy', 1),
#  ('working', 1),
#  ('desk.', 1),
#  ('He', 1),
#  ('produced', 1),
#  ('receipts', 1),
#  ('lo', 1),
#  ('behold', 1),
#  ('using', 1),
#  ('name', 1),
#  ('room.', 1),
#  ('signature', 1),
#  ("wasn't", 1),
#  ('close.', 1),
#  ('Randy', 1),
#  ('immediately', 1),
#  ('removed', 1),
#  ('Again,', 1),
#  ('no', 1),
#  ('accommodation', 1),
#  ('offered.', 1),
#  ("It's", 1),
#  ('looking', 1),
#  ('hotel,', 1),
#  ('maybe', 1),
#  ('three', 1),
#  ('stars', 1),
#  ('never', 1),
#  ('here', 1),
#  ('again', 1),
#  ('caution', 1),
#  ('anyone', 1),
#  ('does', 1),
#  ('refuse', 1),
#  ('closely', 1),
#  ('Follow', 1),
#  ('GM', 1),
#  ('go', 1),
#  ('concerns.', 1),
#  ('Very', 1),
#  ('gracious', 1),
#  ('appreciated', 1),
#  ('spent', 1),
#  ('going', 1),
#  ('visit.', 1)]

# %%
from collections import Counter
