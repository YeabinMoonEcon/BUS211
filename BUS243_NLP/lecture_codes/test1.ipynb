# %%
with open('/Users/yeabinmoon/Downloads/train.txt', 'r') as f:
    contents = f.read()

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
df = TreebankWordTokenizer().tokenize(contents)

# %%
from collections import Counter

# %%
import nltk
stopwords = nltk.corpus.stopwords.words('english')

# %%
#tokens = [x for x in df if x not in stopwords]
kite_counts = Counter(df)
kite_counts
# Out:
# Counter({'=': 29570,
#          'Valkyria': 54,
#          'Chronicles': 47,
#          'III': 231,
#          'Senjō': 5,
#          'no': 1199,
#          '3': 1601,
#          ':': 3806,
#          '<': 54638,
#          'unk': 54625,
#          '>': 54635,
#          '(': 11992,
#          'Japanese': 255,
#          '戦場のヴァルキュリア3': 3,
#          ',': 102612,
#          'lit': 26,
#          '.': 76595,
#          'of': 56889,
#          'the': 113161,
#          'Battlefield': 4,
#          ')': 12004,
#          'commonly': 114,
#          'referred': 206,
#          'to': 39190,
#          'as': 14021,
#          'outside': 281,
#          'Japan': 212,
#          'is': 11637,
#          'a': 34237,
#          'tactical': 25,
#          'role': 588,
#          '@': 45598,
#          '-': 17144,
#          'playing': 316,
#          'video': 614,
#          'game': 1846,
#          'developed': 424,
#          'by': 12148,
#          'Sega': 9,
#          'and': 50603,
# ...

# %%
kite_counts.most_common()
# Out:
# [('the', 113161),
#  (',', 102612),
#  ('.', 76595),
#  ('of', 56889),
#  ('<', 54638),
#  ('>', 54635),
#  ('unk', 54625),
#  ('and', 50603),
#  ('@', 45598),
#  ('in', 39453),
#  ('to', 39190),
#  ('a', 34237),
#  ('=', 29570),
#  ('``', 28309),
#  ('was', 20985),
#  ('The', 17602),
#  ('-', 17144),
#  ('that', 14135),
#  ('as', 14021),
#  ("'s", 14002),
#  ('on', 13678),
#  ('for', 13307),
#  ('with', 12606),
#  ('by', 12148),
#  (')', 12004),
#  ('(', 11992),
#  ('is', 11637),
#  ('from', 8941),
#  ('his', 8395),
#  ('at', 8186),
#  ('were', 7330),
#  ('it', 6748),
#  ('he', 5947),
#  ('an', 5895),
#  ('had', 5698),
#  ('which', 5543),
#  ('In', 5525),
#  ('be', 4787),
#  ('are', 4669),
#  (';', 4224),
#  ('their', 4127),
#  ('not', 4050),
#  ('but', 4035),
#  ('first', 3978),
#  ('–', 3934),
#  (':', 3806),
#  ('also', 3746),
#  ('its', 3697),
#  ('or', 3636),
#  ('her', 3486),
#  ('have', 3442),
#  ('one', 3351),
#  ('has', 3322),
#  ('been', 3257),
#  ('two', 3238),
# ...
